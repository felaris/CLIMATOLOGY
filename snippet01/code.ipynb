# %%
#importing libraries 
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd
from pathlib import Path
import netCDF4 as nc
from netCDF4 import Dataset
from mpl_toolkits.basemap  import Basemap, addcyclic, shiftgrid
# %matplotlib inline

# %%
#importing the data and reading dataset into the code
filename = Path('_grib2netcdf-webmars-public-svc-green-005-6fe5cac1a363ec1525f54343b6cc9fd8-XM_YF6.nc')

#Data = Dataset(filename, mode='r')
Data = Dataset(filename)
#Data
for dim in Data.dimensions.values():
    print(dim)

#print(Data['sp'])
#surf = Data['sp'][:]
# Out:
# <class 'netCDF4._netCDF4.Dimension'>: name = 'longitude', size = 65
# <class 'netCDF4._netCDF4.Dimension'>: name = 'latitude', size = 67
# <class 'netCDF4._netCDF4.Dimension'> (unlimited): name = 'time', size = 72

# %%
# Testing Basemap
m = Basemap(width=12000000,height=9000000,projection='lcc',
            resolution=None,lat_1=-40,lat_2=-20,lat_0=15,lon_0=-10)
m.bluemarble()
plt.show()

# %%
lons = Data.variables['longitude'][:]
lats = Data.variables['latitude'][:]
tmax = Data.variables['sp'][:]

sp_unit = Data.variables['sp'].units
