# %%
#importing libraries 
import matplotlib.pyplot as plt 
import xarray as xr
import numpy as np
import pandas as pd
from pathlib import Path
import netCDF4 as nc
from netCDF4 import Dataset
from netCDF4 import Dataset as NetCDFFile 
from mpl_toolkits.basemap  import Basemap, addcyclic, shiftgrid
import matplotlib.patches as mpatches
# %matplotlib inline

# %%
#importing the data and reading dataset into the code
filename = Path('_grib2netcdf-webmars-public-svc-green-005-6fe5cac1a363ec1525f54343b6cc9fd8-XM_YF6.nc')

ds = xr.open_dataset(filename)
ds
#ds = NetCDFFile(filename)
#ds
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 67, longitude: 65, time: 72)
# Coordinates:
#   * longitude  (longitude) float32 -23.0 -22.25 -21.5 -20.75 ... 23.5 24.25 25.0
#   * latitude   (latitude) float32 39.5 38.75 38.0 37.25 ... -8.5 -9.25 -10.0
#   * time       (time) datetime64[ns] 2010-01-01 ... 2010-12-01T15:00:00
# Data variables:
#     sp         (time, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2021-07-23 16:33:34 GMT by grib_to_netcdf-2.22.0: grib_to_n...

# %%
# Testing Basemap
m = Basemap(width=12000000,height=9000000,projection='lcc',
            resolution=None,lat_1=40,lat_2=-25,lat_0=15,lon_0=-16)
m.bluemarble()
plt.show()
